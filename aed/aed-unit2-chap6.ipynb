# %% [raw]
# # Carregamento e Armazenamento de Dados, e Formato de Arquivos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pwd
# Out:
# /home/neo/Dropbox/Ifes/3_JEFF/2 - Pré-processamento de dados

# %%
# !ls
# Out:
# ex2.csv   ex3.txt   ex5.csv   ex6-out.json  unit2-chap6.ipynb
# ex3a.txt  ex5a.csv  ex6.json  mindex.csv

# %%
# !cat ex2.csv
# Out:
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
df = pd.read_csv('ex2.csv', names=['a', 'b', 'c', 'd', 'message'])

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df = pd.read_csv('ex2.csv', names=['a', 'b', 'c', 'd', 'message'], 
                 index_col='message')

# %%
df
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
df.loc['foo']
# Out:
# a     9
# b    10
# c    11
# d    12
# Name: foo, dtype: int64

# %%
# !cat mindex.csv
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16

# %%
df = pd.read_csv('mindex.csv', index_col=['key1', 'key2'])

# %%
df
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
df.loc['one', 'a']
# Out:
# value1    1
# value2    2
# Name: (one, a), dtype: int64

# %%
df.loc['one']
# Out:
#       value1  value2
# key2
# a          1       2
# b          3       4
# c          5       6
# d          7       8

# %%
# !cat ex3.txt
# Out:
#     A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382 1.100491

# %%
df = pd.read_table('ex3.txt', sep='\s+')

# %%
df
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
df1 = pd.read_table('ex3a.txt', sep='\s+')

# %%
df1
# Out:
#                 A         B         C
# aaa xxx -0.264438 -1.026059 -0.619500
#     xxy -0.274438 -1.036059 -0.659500
# bbb yyy  0.927272  0.302904 -0.032399
# ccc zzz -0.264273 -0.386314 -0.217601
# ddd www -0.871858 -0.348382  1.100491

# %%
df1.loc['aaa', 'xxx']
# Out:
# A   -0.264438
# B   -1.026059
# C   -0.619500
# Name: (aaa, xxx), dtype: float64

# %%
df1.loc['aaa']
# Out:
#             A         B       C
# xxx -0.264438 -1.026059 -0.6195
# xxy -0.274438 -1.036059 -0.6595

# %%
# !cat ex5.csv
# Out:
# something,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6,,8,world
# three,9,10,11,12,foo

# %%
df = pd.read_csv('ex5.csv')

# %%
df
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df.to_csv('ex5a.csv', sep=';')

# %%
# !cat ex5a.csv
# Out:
# ;something;a;b;c;d;message
# 0;one;1;2;3.0;4;
# 1;two;5;6;;8;world
# 2;three;9;10;11.0;12;foo

# %%
obj = """
{"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"],
"pet": null,
"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
{"name": "Katie", "age": 38,
"pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
obj
# Out:
# '\n{"name": "Wes",\n"places_lived": ["United States", "Spain", "Germany"],\n"pet": null,\n"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},\n{"name": "Katie", "age": 38,\n"pets": ["Sixes", "Stache", "Cisco"]}]\n}\n'

# %%
import json

# %%
o = json.loads(obj)

# %%
o
# Out:
# {'name': 'Wes',
#  'pet': None,
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'siblings': [{'age': 30, 'name': 'Scott', 'pets': ['Zeus', 'Zuko']},
#   {'age': 38, 'name': 'Katie', 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
o['siblings']
# Out:
# [{'age': 30, 'name': 'Scott', 'pets': ['Zeus', 'Zuko']},
#  {'age': 38, 'name': 'Katie', 'pets': ['Sixes', 'Stache', 'Cisco']}]

# %%
df = pd.DataFrame(o['siblings'], columns=['name', 'age'])

# %%
df
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %%
# !cat ex6.json
# Out:
# [{"a": 1, "b": 2, "c": 3},
# {"a": 4, "b": 5, "c": 6},
# {"a": 7, "b": 8, "c": 9}]

# %%
df = pd.read_json('ex6.json')

# %%
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.to_json('ex6-out.json', orient='records')

# %%
# !cat ex6-out.json
# Out:
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %%
tables = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
len(tables)
# Out:
# 1

# %%
df = tables[0]

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                  Washington Federal Bank for Savings             Chicago
# 1      The Farmers and Merchants State Bank of Argonia             Argonia
# 2                                  Fayette County Bank          Saint Elmo
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 4                                       First NBC Bank         New Orleans
# 5                                        Proficio Bank  Cottonwood Heights
# 6                        Seaway Bank and Trust Company             Chicago
# 7                               Harvest Community Bank          Pennsville
# 8                                          Allied Bank            Mulberry
# 9                         The Woodbury Banking Company            Woodbury
# 10                              First CornerStone Bank     King of Prussia
# ...

# %%
pd.to_datetime(df['Closing Date'])
# Out:
# 0     2017-12-15
# 1     2017-10-13
# 2     2017-05-26
# 3     2017-05-05
# 4     2017-04-28
# 5     2017-03-03
# 6     2017-01-27
# 7     2017-01-13
# 8     2016-09-23
# 9     2016-08-19
# 10    2016-05-06
# 11    2016-04-29
# 12    2016-03-11
# 13    2015-10-02
# 14    2015-10-02
# 15    2015-07-10
# 16    2015-05-08
# 17    2015-02-27
# 18    2015-02-13
# 19    2015-01-23
# 20    2015-01-16
# 21    2014-12-19
# 22    2014-11-07
# 23    2014-10-24
# 24    2014-10-17
# 25    2014-07-25
# 26    2014-07-18
# 27    2014-06-27
# 28    2014-06-20
# 29    2014-06-20
#          ...
# 525   2008-05-09
# 526   2008-03-07
# 527   2008-01-25
# 528   2007-10-04
# 529   2007-09-28
# 530   2007-02-02
# 531   2004-06-25
# 532   2004-03-19
# 533   2004-03-12
# 534   2004-02-14
# 535   2003-11-14
# 536   2003-05-09
# 537   2003-02-07
# 538   2002-12-17
# 539   2002-11-08
# 540   2002-09-30
# 541   2002-06-27
# 542   2002-06-26
# 543   2002-03-28
# 544   2002-03-01
# 545   2002-02-07
# ...

# %%
df['Closing Date'] = pd.to_datetime(df['Closing Date'])

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                  Washington Federal Bank for Savings             Chicago
# 1      The Farmers and Merchants State Bank of Argonia             Argonia
# 2                                  Fayette County Bank          Saint Elmo
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 4                                       First NBC Bank         New Orleans
# 5                                        Proficio Bank  Cottonwood Heights
# 6                        Seaway Bank and Trust Company             Chicago
# 7                               Harvest Community Bank          Pennsville
# 8                                          Allied Bank            Mulberry
# 9                         The Woodbury Banking Company            Woodbury
# 10                              First CornerStone Bank     King of Prussia
# ...

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])

# %%
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %%
data.dropna(inplace=True)

# %%
data
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])

# %%
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %%
data.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
data[data.notnull()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., np.nan, np.nan],
                    [np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])

# %%
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna()
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna(thresh=2)
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 3  NaN  6.5  3.0

# %%
data.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[3] = np.nan

# %%
data
# Out:
#      0    1    2   3
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis=1, how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna(axis=1, thresh=2)
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.randn(7, 3))

# %%
df.iloc[:4,2] = np.nan

# %%
df.iloc[:2,1] = np.nan

# %%
df
# Out:
#           0         1         2
# 0  0.093266       NaN       NaN
# 1  0.749479       NaN       NaN
# 2  0.630865 -0.504156       NaN
# 3  0.436907  1.103259       NaN
# 4 -0.503669  0.250768 -0.215179
# 5 -2.793061 -0.068327 -0.142924
# 6  1.858991  1.723814  1.388040

# %%
df.mean()
# Out:
# 0    0.067540
# 1    0.501072
# 2    0.343312
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#           0         1         2
# 0  0.093266  0.501072  0.343312
# 1  0.749479  0.501072  0.343312
# 2  0.630865 -0.504156  0.343312
# 3  0.436907  1.103259  0.343312
# 4 -0.503669  0.250768 -0.215179
# 5 -2.793061 -0.068327 -0.142924
# 6  1.858991  1.723814  1.388040

# %%
df
# Out:
#           0         1         2
# 0  0.093266       NaN       NaN
# 1  0.749479       NaN       NaN
# 2  0.630865 -0.504156       NaN
# 3  0.436907  1.103259       NaN
# 4 -0.503669  0.250768 -0.215179
# 5 -2.793061 -0.068327 -0.142924
# 6  1.858991  1.723814  1.388040

# %%
data = pd.DataFrame({'k1': ['one', 'two'] * 3 + ['two'],
                     'k2': [1, 1, 2, 3, 3, 4, 4]})

# %%
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data.duplicated(['k1'])
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon',
'Pastrami', 'corned beef', 'Bacon',
'pastrami', 'honey ham', 'nova lox'],
'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})

# %%
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
data['food'].str.upper()
# Out:
# 0          BACON
# 1    PULLED PORK
# 2          BACON
# 3       PASTRAMI
# 4    CORNED BEEF
# 5          BACON
# 6       PASTRAMI
# 7      HONEY HAM
# 8       NOVA LOX
# Name: food, dtype: object

# %%
data['food'] = data['food'].str.upper()

# %%
data
# Out:
#           food  ounces
# 0        BACON     4.0
# 1  PULLED PORK     3.0
# 2        BACON    12.0
# 3     PASTRAMI     6.0
# 4  CORNED BEEF     7.5
# 5        BACON     8.0
# 6     PASTRAMI     3.0
# 7    HONEY HAM     5.0
# 8     NOVA LOX     6.0

# %%
data['food'] = data['food'].str.lower()

# %%
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
data['ounces'].map(lambda x: x*1.5)
# Out:
# 0     6.00
# 1     4.50
# 2    18.00
# 3     9.00
# 4    11.25
# 5    12.00
# 6     4.50
# 7     7.50
# 8     9.00
# Name: ounces, dtype: float64

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'honey ham': 'pig',
'nova lox': 'salmon'
}

# %%
data['animal'] = data['food'].map(meat_to_animal)

# %%
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon
